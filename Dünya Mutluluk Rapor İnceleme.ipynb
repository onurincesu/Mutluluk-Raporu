# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("2015.csv")
b=pd.read_csv("2016.csv")
c=pd.read_csv("2017.csv")
d=pd.read_csv("2018.csv")
e=pd.read_csv("2019.csv")

# %%
a.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
a=a.rename(columns={"Economy (GDP per Capita)":"Economy","Health (Life Expectancy)":"Life Expectancy"
                    ,"Trust (Government Corruption)":"Trust"})

# %%
a.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy', 'Family', 'Life Expectancy', 'Freedom',
#        'Trust', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
a=a.drop(columns={"Generosity","Dystopia Residual","Standard Error","Family","Region","Freedom"})

# %%
a
# Out:
#          Country  Happiness Rank  Happiness Score  Economy  Life Expectancy  \
# 0    Switzerland               1            7.587  1.39651          0.94143
# 1        Iceland               2            7.561  1.30232          0.94784
# 2        Denmark               3            7.527  1.32548          0.87464
# 3         Norway               4            7.522  1.45900          0.88521
# 4         Canada               5            7.427  1.32629          0.90563
# ..           ...             ...              ...      ...              ...
# 153       Rwanda             154            3.465  0.22208          0.42864
# 154        Benin             155            3.340  0.28665          0.31910
# 155        Syria             156            3.006  0.66320          0.72193
# 156      Burundi             157            2.905  0.01530          0.22396
# 157         Togo             158            2.839  0.20868          0.28443
#
#        Trust
# 0    0.41978
# 1    0.14145
# ...

# %%
b.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
b=b.rename(columns={"Economy (GDP per Capita)":"Economy","Trust (Government Corruption)":"Trust",
                    "Health (Life Expectancy)":"Life Expectancy"})

# %%
b=b.drop(columns={"Generosity","Dystopia Residual","Upper Confidence Interval",
               "Lower Confidence Interval","Generosity","Family","Freedom","Region"})

# %%
b
# Out:
#          Country  Happiness Rank  Happiness Score  Economy  Life Expectancy  \
# 0        Denmark               1            7.526  1.44178          0.79504
# 1    Switzerland               2            7.509  1.52733          0.86303
# 2        Iceland               3            7.501  1.42666          0.86733
# 3         Norway               4            7.498  1.57744          0.79579
# 4        Finland               5            7.413  1.40598          0.81091
# ..           ...             ...              ...      ...              ...
# 152        Benin             153            3.484  0.39499          0.21028
# 153  Afghanistan             154            3.360  0.38227          0.17344
# 154         Togo             155            3.303  0.28123          0.24811
# 155        Syria             156            3.069  0.74719          0.62994
# 156      Burundi             157            2.905  0.06831          0.15747
#
#        Trust
# 0    0.44453
# 1    0.41203
# ...

# %%
c=c.rename(columns={"Happiness.Rank":"Happiness Rank","Happiness.Score":"Happiness Score",
                   "Economy..GDP.per.Capita.":"Economy","Trust..Government.Corruption.":"Trust",
                   "Health..Life.Expectancy.":"Life Expectancy"})

# %%
c=c.drop(columns={"Whisker.high","Whisker.low","Dystopia.Residual","Family","Generosity","Freedom"})

# %%
c
# Out:
#                       Country  Happiness Rank  Happiness Score   Economy  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# 150                    Rwanda             151            3.471  0.368746
# 151                     Syria             152            3.462  0.777153
# 152                  Tanzania             153            3.349  0.511136
# 153                   Burundi             154            2.905  0.091623
# 154  Central African Republic             155            2.693  0.000000
#
#      Life Expectancy     Trust
# 0           0.796667  0.315964
# ...

# %%
d.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
d=d.rename(columns={"Overall rank":"Happiness Rank","Country or region":"Country","Score":"Happiness Score",
                   "GDP per capita":"Economy","Perceptions of corruption":"Trust","Healthy life expectancy":"Life Expectancy"})

# %%
d=d.drop(columns={"Generosity","Freedom to make life choices","Social support"})

# %%
d
# Out:
#      Happiness Rank                   Country  Happiness Score  Economy  \
# 0                 1                   Finland            7.632    1.305
# 1                 2                    Norway            7.594    1.456
# 2                 3                   Denmark            7.555    1.351
# 3                 4                   Iceland            7.495    1.343
# 4                 5               Switzerland            7.487    1.420
# ..              ...                       ...              ...      ...
# 151             152                     Yemen            3.355    0.442
# 152             153                  Tanzania            3.303    0.455
# 153             154               South Sudan            3.254    0.337
# 154             155  Central African Republic            3.083    0.024
# 155             156                   Burundi            2.905    0.091
#
#      Life Expectancy  Trust
# 0              0.874  0.393
# 1              0.861  0.340
# ...

# %%
e.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
e=e.rename(columns={"Overall rank":"Happiness Rank","Country or region":"Country","GDP per capita":"Economy",
                   "Score":"Happiness Score","Perceptions of corruption":"Trust","Healthy life expectancy":"Life Expectancy"})

# %%
e=e.drop(columns={"Freedom to make life choices","Generosity","Social support"})

# %%
e
# Out:
#      Happiness Rank                   Country  Happiness Score  Economy  \
# 0                 1                   Finland            7.769    1.340
# 1                 2                   Denmark            7.600    1.383
# 2                 3                    Norway            7.554    1.488
# 3                 4                   Iceland            7.494    1.380
# 4                 5               Netherlands            7.488    1.396
# ..              ...                       ...              ...      ...
# 151             152                    Rwanda            3.334    0.359
# 152             153                  Tanzania            3.231    0.476
# 153             154               Afghanistan            3.203    0.350
# 154             155  Central African Republic            3.083    0.026
# 155             156               South Sudan            2.853    0.306
#
#      Life Expectancy  Trust
# 0              0.986  0.393
# 1              0.996  0.410
# ...

# %%
genel=pd.concat([a,b,c,d,e])

# %%
genel
# Out:
#                       Country  Happiness Rank  Happiness Score  Economy  \
# 0                 Switzerland               1            7.587  1.39651
# 1                     Iceland               2            7.561  1.30232
# 2                     Denmark               3            7.527  1.32548
# 3                      Norway               4            7.522  1.45900
# 4                      Canada               5            7.427  1.32629
# ..                        ...             ...              ...      ...
# 151                    Rwanda             152            3.334  0.35900
# 152                  Tanzania             153            3.231  0.47600
# 153               Afghanistan             154            3.203  0.35000
# 154  Central African Republic             155            3.083  0.02600
# 155               South Sudan             156            2.853  0.30600
#
#      Life Expectancy    Trust
# 0            0.94143  0.41978
# 1            0.94784  0.14145
# ...

# %%
a_ilk=a.head(10)
c_ilk=c.head(10)
d_ilk=d.head(10)
e_ilk=e.head(10)
b_ilk=b.head(10)
e_son=e.tail(10)
color = ['#FF5733', '#FFC300', '#DAF7A6', '#C70039', '#900C3F', '#581845', '#4CAF50', '#008CBA', '#FF9800', '#9C27B0']

fig, axs = plt.subplots(3, 2, figsize=(30, 17))
axs[0,0].bar(a_ilk["Country"],a_ilk["Happiness Score"],color=color)
axs[0,0].set_title("2015 En Mutlu 10 ülke")
axs[0,1].bar(b_ilk["Country"],b_ilk["Happiness Score"],color=color)
axs[0,1].set_title("2016 En Mutlu 10 ülke")
axs[1,0].bar(c_ilk["Country"],c_ilk["Happiness Score"],color=color)
axs[1,0].set_title("2017 En Mutlu 10 ülke")
axs[1,1].bar(d_ilk["Country"],d_ilk["Happiness Score"],color=color)
axs[1,1].set_title("2018 En Mutlu 10 ülke")
axs[2,0].bar(e_ilk["Country"],e_ilk["Happiness Score"],color=color)
axs[2,0].set_title("2019 En Mutlu 10 ülke")
axs[2,1].bar(e_son["Country"],e_son["Happiness Score"],color=color)
axs[2,1].set_title("2019 En Mutsuz 10 ülke")
plt.show()

# %%
df_all = pd.concat([a, b, c, d, e])
genel_skor = df_all.groupby(['Country'])['Happiness Score'].sum()
genel_skor=genel_skor/5
genel_skor=genel_skor.sort_values(ascending=False)
color = ['#FF5733', '#FFC300', '#DAF7A6', '#C70039', '#900C3F', '#581845', '#4CAF50', '#008CBA', '#FF9800', '#9C27B0']
skorlar=genel_skor.head(10)
fig = plt.subplots(figsize =(12, 8))

plt.bar(skorlar.index,skorlar.values,color=color)
plt.title("5 Yılın En Mutlu Ülkeleri Sıralaması")
# Out:
# Text(0.5, 1.0, '5 Yılın En Mutlu Ülkeleri Sıralaması')

# %%
life=e_ilk["Life Expectancy"]
ekonomi=e_ilk["Economy"]
skor=e_ilk["Happiness Score"]/4
bar_width=0.2
ülkeler=e_ilk["Country"]
fig=plt.subplots(figsize=(17,7))
plt.bar(np.arange(len(ülkeler)), skor, width=bar_width, label='Mutluluk Skorları')
plt.bar(np.arange(len(ülkeler)) + bar_width, life, width=bar_width, label='Yaşam Beklentisi')
plt.bar(np.arange(len(ülkeler))+0.4, ekonomi, width=bar_width, label='Ekonomi')
plt.xticks(np.arange(len(ülkeler)) + bar_width / 2, ülkeler)

plt.title("Yaşam Beklentisi ve Mutluluk Puanları")

plt.legend(loc='upper right')
